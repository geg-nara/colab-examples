# %% [markdown]
# <a href="https://colab.research.google.com/github/t-cool/Projects/blob/master/matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('seaborn-darkgrid')

plt.plot([2,1,3])
plt.plot([1,3,2])
plt.plot([2,3,3])
plt.show()
